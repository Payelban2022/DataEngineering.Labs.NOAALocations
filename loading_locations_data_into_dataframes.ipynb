# %%
import pandas as pd
import os
import json

# %% [markdown]
# ## Read a single JSON

# %% [markdown]
# Define a function called read_json. Given a string representing a file path to a json file, this function should open said file and convert its contens into a json object.

# %%
# implement me
def read_json(file_path):
    file = open(file_path)
    data = json.loads(file.read())
    data.pop("metadata")
    return data

# %% [markdown]
# Use the read_json function defined above to read the contents of one of the locations_4.json file acquired in the Data Acquisition Lab.

# %%
file_path = os.path.join('./', 'data', 'locations','location_4.json')

json_contents = read_json(file_path)

# %% [markdown]
# Display the value of the json_contents variable defined above.

# %%
json_contents
# Out:
# {'results': [{'mindate': '1983-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Abu Dhabi, AE',
#    'datacoverage': 0.9977,
#    'id': 'CITY:AE000001'},
#   {'mindate': '1944-03-01',
#    'maxdate': '2022-08-02',
#    'name': 'Ajman, AE',
#    'datacoverage': 0.9992,
#    'id': 'CITY:AE000002'},
#   {'mindate': '1944-03-01',
#    'maxdate': '2022-08-02',
#    'name': 'Dubai, AE',
#    'datacoverage': 0.9992,
#    'id': 'CITY:AE000003'},
#   {'mindate': '1944-03-01',
#    'maxdate': '2022-08-02',
#    'name': 'Sharjah, AE',
#    'datacoverage': 0.9992,
#    'id': 'CITY:AE000006'},
#   {'mindate': '1966-03-02',
#    'maxdate': '2021-08-30',
#    'name': 'Kabul, AF',
#    'datacoverage': 0.9969,
#    'id': 'CITY:AF000007'},
#   {'mindate': '1973-01-02',
#    'maxdate': '2020-12-31',
#    'name': 'Kandahar, AF',
#    'datacoverage': 1,
#    'id': 'CITY:AF000008'},
#   {'mindate': '1877-04-01',
#    'maxdate': '2022-08-02',
#    'name': 'Algiers, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000001'},
#   {'mindate': '1909-11-01',
#    'maxdate': '2022-08-02',
#    'name': 'Annaba, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000002'},
#   {'mindate': '1973-04-01',
#    'maxdate': '2022-08-02',
#    'name': 'Batna, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000003'},
#   {'mindate': '1957-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Bechar, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000004'},
#   {'mindate': '1909-11-01',
#    'maxdate': '2022-08-02',
#    'name': 'Bejaia, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000005'},
#   {'mindate': '1880-05-01',
#    'maxdate': '2022-08-02',
#    'name': 'Constantine, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000006'},
#   {'mindate': '1995-10-01',
#    'maxdate': '2022-08-02',
#    'name': 'Guelma, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000007'},
#   {'mindate': '1888-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Laghouat, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000008'},
#   {'mindate': '1995-10-01',
#    'maxdate': '2022-08-02',
#    'name': 'Medea, AG',
#    'datacoverage': 0.9909,
#    'id': 'CITY:AG000009'},
#   {'mindate': '1976-04-01',
#    'maxdate': '2022-08-02',
#    'name': 'Mostaganem, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000010'},
#   {'mindate': '1957-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Oran, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000011'},
#   {'mindate': '1985-02-01',
#    'maxdate': '2022-08-02',
#    'name': 'Oum el Bouaghi, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000012'},
#   {'mindate': '1981-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Saida, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000013'},
#   {'mindate': '1995-10-01',
#    'maxdate': '2022-08-02',
#    'name': 'Sidi-Bel-Abbes, AG',
#    'datacoverage': 0.9995,
#    'id': 'CITY:AG000014'},
#   {'mindate': '1957-12-31',
#    'maxdate': '2022-08-02',
#    'name': 'Skikda, AG',
#    'datacoverage': 0.9993,
#    'id': 'CITY:AG000015'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2014-02-01',
#    'name': 'Tamanrasset, AG',
#    'datacoverage': 0.9973,
#    'id': 'CITY:AG000016'},
#   {'mindate': '1981-01-01',
#    'maxdate': '2022-08-02',
#    'name': 'Tlemcen, AG',
#    'datacoverage': 1,
#    'id': 'CITY:AG000017'},
#   {'mindate': '1881-07-01',
#    'maxdate': '1992-01-31',
#    'name': 'Baku, AJ',
#    'datacoverage': 0.991,
#    'id': 'CITY:AJ000001'},
#   {'mindate': '1925-09-01',
#    'maxdate': '1991-12-31',
#    'name': 'Naxcivian, AJ',
#    'datacoverage': 1,
#    'id': 'CITY:AJ000002'}]}

# %% [markdown]
# ## Convert JSON Into a DataFrame

# %% [markdown]
# Using the json_contents variable, create a Pandas dataframe.

# %%
# Create DataFrame here.
# df= pd.read_json("./data/locations/location_4.json", orient="columns")
df = pd.DataFrame(json_contents.get('results'))

# %% [markdown]
# Display the contents of the DataFrame.

# %%
# Display contents of the DataFrame here.
df
# Out:
#        mindate     maxdate                name  datacoverage             id
# 0   1983-01-01  2022-08-02       Abu Dhabi, AE        0.9977  CITY:AE000001
# 1   1944-03-01  2022-08-02           Ajman, AE        0.9992  CITY:AE000002
# 2   1944-03-01  2022-08-02           Dubai, AE        0.9992  CITY:AE000003
# 3   1944-03-01  2022-08-02         Sharjah, AE        0.9992  CITY:AE000006
# 4   1966-03-02  2021-08-30           Kabul, AF        0.9969  CITY:AF000007
# 5   1973-01-02  2020-12-31        Kandahar, AF        1.0000  CITY:AF000008
# 6   1877-04-01  2022-08-02         Algiers, AG        1.0000  CITY:AG000001
# 7   1909-11-01  2022-08-02          Annaba, AG        1.0000  CITY:AG000002
# 8   1973-04-01  2022-08-02           Batna, AG        1.0000  CITY:AG000003
# 9   1957-01-01  2022-08-02          Bechar, AG        1.0000  CITY:AG000004
# 10  1909-11-01  2022-08-02          Bejaia, AG        1.0000  CITY:AG000005
# 11  1880-05-01  2022-08-02     Constantine, AG        1.0000  CITY:AG000006
# 12  1995-10-01  2022-08-02          Guelma, AG        1.0000  CITY:AG000007
# 13  1888-01-01  2022-08-02        Laghouat, AG        1.0000  CITY:AG000008
# 14  1995-10-01  2022-08-02           Medea, AG        0.9909  CITY:AG000009
# 15  1976-04-01  2022-08-02      Mostaganem, AG        1.0000  CITY:AG000010
# 16  1957-01-01  2022-08-02            Oran, AG        1.0000  CITY:AG000011
# 17  1985-02-01  2022-08-02  Oum el Bouaghi, AG        1.0000  CITY:AG000012
# 18  1981-01-01  2022-08-02           Saida, AG        1.0000  CITY:AG000013
# 19  1995-10-01  2022-08-02  Sidi-Bel-Abbes, AG        0.9995  CITY:AG000014
# 20  1957-12-31  2022-08-02          Skikda, AG        0.9993  CITY:AG000015
# 21  1940-01-01  2014-02-01     Tamanrasset, AG        0.9973  CITY:AG000016
# 22  1981-01-01  2022-08-02         Tlemcen, AG        1.0000  CITY:AG000017
# 23  1881-07-01  1992-01-31            Baku, AJ        0.9910  CITY:AJ000001
# 24  1925-09-01  1991-12-31       Naxcivian, AJ        1.0000  CITY:AJ000002

# %% [markdown]
# How many records are in the DataFrame? How many columns does each record have?

# %% [markdown]
# Filter the contents of the DataFrame to only show records where the name column contains the string "Durham".

# %%
df.shape
# Out:
# (25, 5)

# %%
df.loc[df['name'].str.contains('Durham')]
# Out:
# Empty DataFrame
# Columns: [mindate, maxdate, name, datacoverage, id]
# Index: []

# %%
df.loc[df['name'].str.contains('AJ')]
# Out:
#        mindate     maxdate           name  datacoverage             id
# 23  1881-07-01  1992-01-31       Baku, AJ         0.991  CITY:AJ000001
# 24  1925-09-01  1991-12-31  Naxcivian, AJ         1.000  CITY:AJ000002

# %% [markdown]
# ## Read Multiple JSON Files

# %% [markdown]
# Define a function called read_all_json_files. Given a string representing a path to a directory, this function should read all of the json files and return a Pandas DataFrame containing all of the objects. In addition to the data from the files, this DataFrame should also contain an additional column called "source". The source column should be populated with the name of the file from which this record originated from.

# %%
# implement me
def read_all_json_files(JSON_ROOT):
    files = os.listdir(JSON_ROOT)
    json_files = sorted([file for file in files if file.endswith(".json")])
    first = True
    for file in json_files:
        if first:
            json_contents = read_json(f"{JSON_ROOT}/{file}")
            df = pd.DataFrame(json_contents['results'])
            df['source']= file
            first=False
        else:
            json_contents = read_json(f"{JSON_ROOT}/{file}")
            temp = pd.DataFrame(json_contents['results'])
            temp['source'] = file
            df = df.append(temp,ignore_index=True)
    return df

# %% [markdown]
# Use the read_all_json_files function above to read the contents of all locations file acquired in the the Data Acquisition Lab.
# Hint: It is easier if you put all of those files in a dedicated subdirectory ex: (./data/locations/)

# %%
df = read_all_json_files('./data/locations')
# Out:
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)
# /var/folders/3x/9l24p0_15v7f2c1jgn7mjslc0000gp/T/ipykernel_42849/198398308.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp,ignore_index=True)

# %% [markdown]
# What is the shape of the DataFrame? Does this match the number of columns and records you expected?

# %%
df.shape
# Out:
# (975, 6)

# %%
# Validate the shape of the DataFrame here

# %% [markdown]
# Show the first few records of the DataFrame.

# %%
# Show the first few rec
df.head()
# Out:
#       mindate     maxdate           name  datacoverage             id  \
# 0  1983-01-01  2022-08-02  Abu Dhabi, AE        0.9977  CITY:AE000001
# 1  1944-03-01  2022-08-02      Ajman, AE        0.9992  CITY:AE000002
# 2  1944-03-01  2022-08-02      Dubai, AE        0.9992  CITY:AE000003
# 3  1944-03-01  2022-08-02    Sharjah, AE        0.9992  CITY:AE000006
# 4  1966-03-02  2021-08-30      Kabul, AF        0.9969  CITY:AF000007
#
#             source
# 0  location_0.json
# 1  location_0.json
# 2  location_0.json
# 3  location_0.json
# 4  location_0.json

# %% [markdown]
# Show the last few records of the DataFrame.

# %%
# Show the last few records
df.tail()
# Out:
#         mindate     maxdate             name  datacoverage             id  \
# 970  1957-12-31  2022-08-02       Skikda, AG        0.9993  CITY:AG000015
# 971  1940-01-01  2014-02-01  Tamanrasset, AG        0.9973  CITY:AG000016
# 972  1981-01-01  2022-08-02      Tlemcen, AG        1.0000  CITY:AG000017
# 973  1881-07-01  1992-01-31         Baku, AJ        0.9910  CITY:AJ000001
# 974  1925-09-01  1991-12-31    Naxcivian, AJ        1.0000  CITY:AJ000002
#
#               source
# 970  location_9.json
# 971  location_9.json
# 972  location_9.json
# 973  location_9.json
# 974  location_9.json

# %% [markdown]
# ## Validate Records Are Unique

# %% [markdown]
# Provide two different ways to determine there are no duplicate records.
# Hint: The id field should be unique.

# %%
# one day to determine there are not duplicate records
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [mindate, maxdate, name, datacoverage, id, source]
# Index: []

# %%
# another way to determine there are no duplicate records
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Peking In

# %% [markdown]
# Show the record with id "CITY:TU000041". Which file did it come from?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mindate       975 non-null    object
#  1   maxdate       975 non-null    object
#  2   name          975 non-null    object
#  3   datacoverage  975 non-null    float64
#  4   id            975 non-null    object
#  5   source        975 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 45.8+ KB

# %%
df.loc[df['id'] == "CITY:TU000041"]
# Out:
# Empty DataFrame
# Columns: [mindate, maxdate, name, datacoverage, id, source]
# Index: []

# %%
df.loc[df['id'] == "CITY:AG000017"]
# Out:
#         mindate     maxdate         name  datacoverage             id  \
# 22   1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 47   1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 72   1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 97   1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 122  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 147  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 172  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 197  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 222  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 247  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 272  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 297  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 322  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 347  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 372  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 397  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 422  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 447  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 472  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 497  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 522  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 547  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 572  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 597  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 622  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 647  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 672  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 697  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 722  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 747  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 772  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 797  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 822  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 847  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 872  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 897  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 922  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 947  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
# 972  1981-01-01  2022-08-02  Tlemcen, AG           1.0  CITY:AG000017
#
#                source
# 22    location_0.json
# 47    location_1.json
# 72   location_10.json
# 97   location_11.json
# 122  location_12.json
# 147  location_13.json
# 172  location_14.json
# 197  location_15.json
# 222  location_16.json
# 247  location_17.json
# 272  location_18.json
# 297  location_19.json
# 322   location_2.json
# 347  location_20.json
# 372  location_21.json
# 397  location_22.json
# 422  location_23.json
# 447  location_24.json
# 472  location_25.json
# 497  location_26.json
# 522  location_27.json
# 547  location_28.json
# 572  location_29.json
# 597   location_3.json
# 622  location_30.json
# 647  location_31.json
# 672  location_32.json
# 697  location_33.json
# 722  location_34.json
# 747  location_35.json
# 772  location_36.json
# 797  location_37.json
# 822  location_38.json
# 847   location_4.json
# 872   location_5.json
# 897   location_6.json
# 922   location_7.json
# 947   location_8.json
# 972   location_9.json

# %% [markdown]
# Show the record with id "CLIM:0405". Which file did it come from?

# %%
# 
df.loc[df['id'] == "CLIM:0405"]
# Out:
# Empty DataFrame
# Columns: [mindate, maxdate, name, datacoverage, id, source]
# Index: []

# %% [markdown]
# How many unique values are there for the source column in the DataFrame?

# %%
# 
len(pd.unique(df['source']))
# Out:
# 39

# %% [markdown]
# How many records did the locations_38.json file contain?

# %%
# 
len(df.loc[df['source'] == 'location_38.json'])
# Out:
# 25

# %% [markdown]
# We will work with this DataFrame in a subsequent part of the lab. Instead of repeating all of this work again, let's export the DataFrame to a pickled file.

# %%
# export DataFrame to a pickled file called locations_data_frame.pickle. Save it to the data directory.
df.to_pickle('locations.pkl')

# %%
df1 = pd.read_pickle('./locations.pkl')
df1.head()
# Out:
#       mindate     maxdate           name  datacoverage             id  \
# 0  1983-01-01  2022-08-02  Abu Dhabi, AE        0.9977  CITY:AE000001
# 1  1944-03-01  2022-08-02      Ajman, AE        0.9992  CITY:AE000002
# 2  1944-03-01  2022-08-02      Dubai, AE        0.9992  CITY:AE000003
# 3  1944-03-01  2022-08-02    Sharjah, AE        0.9992  CITY:AE000006
# 4  1966-03-02  2021-08-30      Kabul, AF        0.9969  CITY:AF000007
#
#             source
# 0  location_0.json
# 1  location_0.json
# 2  location_0.json
# 3  location_0.json
# 4  location_0.json
